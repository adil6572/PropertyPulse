# %%
import pandas as pd
import json

# %%
with open("./response.json", "r") as file:
    data=json.load(file)

# %%
def flatten_dict(d, parent_key='', sep='_'):
    items = []
    for k, v in d.items():
        new_key = parent_key + sep + k if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten_dict(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# %%
def tranform_response(data: dict):
    if data is not None:
        properties= data.get("properties",'')
        if properties:
            results = [flatten_dict(d) for d in properties]
            df=pd.DataFrame(results)
    
    return df

# %%
tranform_response(data)
# Out:
#     property_id  list_price    status  listing_id  \
# 0    2769011270      399000  for_sale  2965588367
# 1    1142069273      600000  for_sale  2965694229
# 2    2484506523      599000  for_sale  2959469993
# 3    2350354300      549950  for_sale  2965341897
# 4    1825932732      587000  for_sale  2965607706
# ..          ...         ...       ...         ...
# 202  2595746678      467000  for_sale  2965363732
# 203  2083440395      470000  for_sale  2965467777
# 204  1315128458      575000  for_sale  2962848990
# 205  2400291886      440000  for_sale  2963526981
# 206  1404380391      425000  for_sale  2964454962
#
#                                              permalink  \
# 0    https://www.realtor.com/realestateandhomes-det...
# 1    https://www.realtor.com/realestateandhomes-det...
# 2    https://www.realtor.com/realestateandhomes-det...
# 3    https://www.realtor.com/realestateandhomes-det...
# 4    https://www.realtor.com/realestateandhomes-det...
# ..                                                 ...
# 202  https://www.realtor.com/realestateandhomes-det...
# 203  https://www.realtor.com/realestateandhomes-det...
# 204  https://www.realtor.com/realestateandhomes-det...
# 205  https://www.realtor.com/realestateandhomes-det...
# 206  https://www.realtor.com/realestateandhomes-det...
#
#                                          primary_photo  description_beds  \
# 0    https://ap.rdcpix.com/bfbe22246f91502763b8ee91...                 3
# 1    https://ap.rdcpix.com/ba7307d8f912ede7e832ffa2...                 3
# 2    https://ap.rdcpix.com/77b9cc2e89ac789f7f2e27f5...                 3
# 3    https://ap.rdcpix.com/657b8269268d4e99102f034c...                 2
# 4    https://ap.rdcpix.com/7d9810be229e1fb18a4f7ec7...                 5
# ..                                                 ...               ...
# 202  https://ap.rdcpix.com/8a14ad9fb64c89a1de47e4c1...                 2
# 203  https://ap.rdcpix.com/174bb1855c8987d1ea4f1e7b...                 2
# 204  https://ap.rdcpix.com/694418fd38e68f969e746789...                 2
# 205  https://ap.rdcpix.com/a9449708170f87ca7aca6602...                 1
# 206                                                                    1
#
#     description_baths  description_sqft  description_lot_sqft  ...  \
# 0                   1               967                  6883  ...
# 1                   2              1443                  8052  ...
# 2                   3              2500                 10496  ...
# 3                   1               869                  8231  ...
# 4                   3              1213                  3510  ...
# ..                ...               ...                   ...  ...
# 202                 1               988                  4845  ...
# 203                 1               720                  5406  ...
# 204                 1               832                  6694  ...
# 205                 1               832                  5402  ...
# 206                 1               684                  2646  ...
#
#     location_county_name  location_county_fips_code flags_is_coming_soon  \
# 0            Los Angeles                      06037                 None
# 1            Los Angeles                      06037                 None
# 2            Los Angeles                      06037                 None
# 3            Los Angeles                      06037                 None
# 4            Los Angeles                      06037                 None
# ..                   ...                        ...                  ...
# 202          Los Angeles                      06037                 None
# 203          Los Angeles                      06037                 None
# 204          Los Angeles                      06037                 None
# 205          Los Angeles                      06037                 None
# 206          Los Angeles                      06037                 None
#
#     flags_is_new_listing flags_is_price_reduced flags_is_foreclosure  \
# 0                   True                   None                 None
# 1                   True                   None                 None
# 2                  False                   None                 None
# 3                  False                   None                 None
# 4                   True                   None                 None
# ..                   ...                    ...                  ...
# 202                False                   None                 None
# 203                False                   None                 None
# 204                False                   None                 None
# 205                False                   None                 None
# 206                False                   None                 None
#
#     flags_is_new_construction flags_is_pending flags_is_contingent  \
# 0                        None             None                None
# 1                        None             None                None
# 2                        None             None                None
# 3                        None             None                None
# 4                        None             None                None
# ..                        ...              ...                 ...
# 202                      None             True                None
# 203                      None             True                None
# 204                      None             True                None
# 205                      None             True                None
# 206                      None             True                None
#
#                list_date
# 0    2024-03-28 21:15:38
# 1    2024-04-02 01:57:32
# 2    2023-09-07 23:11:05
# 3    2024-03-21 05:17:07
# 4    2024-03-29 12:12:31
# ..                   ...
# 202  2024-03-21 18:58:34
# 203  2024-03-25 18:27:33
# 204  2024-01-02 19:46:53
# 205  2024-01-26 22:41:43
# 206  2024-02-26 20:17:49
#
# [207 rows x 31 columns]

# %%
results = [flatten_dict(d) for d in data['properties']]

# %%
results
# Out:
# [{'property_id': '2769011270',
#   'list_price': 399000,
#   'status': 'for_sale',
#   'listing_id': '2965588367',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/7841-Wentworth-St_Sunland_CA_91040_M27690-11270',
#   'primary_photo': 'https://ap.rdcpix.com/bfbe22246f91502763b8ee91d7e6554cl-m2473175958s.jpg',
#   'description_beds': 3,
#   'description_baths': '1',
#   'description_sqft': 967,
#   'description_lot_sqft': 6883,
#   'description_type': 'single_family',
#   'description_sold_price': 76000,
#   'description_sold_date': '1980-08-26',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=7841%20Wentworth%20St%2C%20Sunland%2C%20CA%2091040&size=640x480&source=outdoor&signature=TQGCcj3938lqVdOVsH3CAVFT5g8=',
#   'location_address_line': '7841 Wentworth St',
#   'location_address_postal_code': '91040',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Sunland',
#   'location_address_coordinate_lat': 34.267205,
#   'location_address_coordinate_lon': -118.304134,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': True,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2024-03-28 21:15:38'},
#  {'property_id': '1142069273',
#   'list_price': 600000,
#   'status': 'for_sale',
#   'listing_id': '2965694229',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/10038-Wisner-Ave_Mission-Hills_CA_91345_M11420-69273',
#   'primary_photo': 'https://ap.rdcpix.com/ba7307d8f912ede7e832ffa261c2438dl-m891580861s.jpg',
#   'description_beds': 3,
#   'description_baths': '2',
#   'description_sqft': 1443,
#   'description_lot_sqft': 8052,
#   'description_type': 'single_family',
#   'description_sold_price': None,
#   'description_sold_date': None,
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=10038%20Wisner%20Ave%2C%20Mission%20Hills%2C%20CA%2091345&size=640x480&source=outdoor&signature=500HvxEeqA2Q9ENtybRFt4fSalc=',
#   'location_address_line': '10038 Wisner Ave',
#   'location_address_postal_code': '91345',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Mission Hills',
#   'location_address_coordinate_lat': 34.252967,
#   'location_address_coordinate_lon': -118.461667,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': True,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2024-04-02 01:57:32'},
#  {'property_id': '2484506523',
#   'list_price': 599000,
#   'status': 'for_sale',
#   'listing_id': '2959469993',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/14900-Round-Valley-Dr_Sherman-Oaks_CA_91403_M24845-06523',
#   'primary_photo': 'https://ap.rdcpix.com/77b9cc2e89ac789f7f2e27f5b1484833l-m1546596996s.jpg',
#   'description_beds': 3,
#   'description_baths': '3',
#   'description_sqft': 2500,
#   'description_lot_sqft': 10496,
#   'description_type': 'single_family',
#   'description_sold_price': 85000,
#   'description_sold_date': '2015-06-25',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=14900%20Round%20Valley%20Dr%2C%20Sherman%20Oaks%2C%20CA%2091403&size=640x480&source=outdoor&signature=LBRJBlqzC07NpHvDOvVZfxtqdzk=',
#   'location_address_line': '14900 Round Valley Dr',
#   'location_address_postal_code': '91403',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Sherman Oaks',
#   'location_address_coordinate_lat': 34.143501,
#   'location_address_coordinate_lon': -118.455841,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': False,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2023-09-07 23:11:05'},
#  {'property_id': '2350354300',
#   'list_price': 549950,
#   'status': 'for_sale',
#   'listing_id': '2965341897',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/8764-Sharp-Ave_Sun-Valley_CA_91352_M23503-54300',
#   'primary_photo': 'https://ap.rdcpix.com/657b8269268d4e99102f034c32ac5ccal-m484562082s.jpg',
#   'description_beds': 2,
#   'description_baths': '1',
#   'description_sqft': 869,
#   'description_lot_sqft': 8231,
#   'description_type': 'single_family',
#   'description_sold_price': None,
#   'description_sold_date': None,
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=8764%20Sharp%20Ave%2C%20Sun%20Valley%2C%20CA%2091352&size=640x480&source=outdoor&signature=sW2jjBFauVecNkFsXdhFjYMS3rE=',
#   'location_address_line': '8764 Sharp Ave',
#   'location_address_postal_code': '91352',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Sun Valley',
#   'location_address_coordinate_lat': 34.229136,
#   'location_address_coordinate_lon': -118.406118,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': False,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2024-03-21 05:17:07'},
#  {'property_id': '1825932732',
#   'list_price': 587000,
#   'status': 'for_sale',
#   'listing_id': '2965607706',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/8728-Beach-St_Los-Angeles_CA_90002_M18259-32732',
#   'primary_photo': 'https://ap.rdcpix.com/7d9810be229e1fb18a4f7ec708b87d91l-m2530720275s.jpg',
#   'description_beds': 5,
#   'description_baths': '3',
#   'description_sqft': 1213,
#   'description_lot_sqft': 3510,
#   'description_type': 'single_family',
#   'description_sold_price': 15000,
#   'description_sold_date': '1986-09-24',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=8728%20Beach%20St%2C%20Los%20Angeles%2C%20CA%2090002&size=640x480&source=outdoor&signature=cXIN7qEYmpX08lLVhPvqvrn_kkY=',
#   'location_address_line': '8728 Beach St',
#   'location_address_postal_code': '90002',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 33.957446,
#   'location_address_coordinate_lon': -118.241626,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': True,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2024-03-29 12:12:31'},
#  {'property_id': '2661934844',
#   'list_price': 599999,
#   'status': 'for_sale',
#   'listing_id': '2963345739',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/13637-Terra-Bella-St_Arleta_CA_91331_M26619-34844',
#   'primary_photo': 'https://ap.rdcpix.com/9ab12f12acef220c03c36a2e92bf4966l-m1321144764s.jpg',
#   'description_beds': 3,
#   'description_baths': '2',
#   'description_sqft': 1156,
#   'description_lot_sqft': 6753,
#   'description_type': 'single_family',
#   'description_sold_price': 135000,
#   'description_sold_date': '2000-06-06',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=13637%20N%20Terra%20Bella%20St%2C%20Arleta%2C%20CA%2091331&size=640x480&source=outdoor&signature=uyuQyjc-Q8-gC2jHya4deCV_5X8=',
#   'location_address_line': '13637 N Terra Bella St',
#   'location_address_postal_code': '91331',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Arleta',
#   'location_address_coordinate_lat': 34.249922,
#   'location_address_coordinate_lon': -118.430341,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': False,
#   'flags_is_price_reduced': False,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2024-01-20 06:57:34'},
#  {'property_id': '1955767276',
#   'list_price': 550000,
#   'status': 'for_sale',
#   'listing_id': '2965814639',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/9711-Bandera-St_Los-Angeles_CA_90002_M19557-67276',
#   'primary_photo': 'https://ap.rdcpix.com/cc19d7a72d6b2a558e0db17e035d32f2l-m2693298930s.jpg',
#   'description_beds': 3,
#   'description_baths': '2',
#   'description_sqft': 1542,
#   'description_lot_sqft': 3324,
#   'description_type': 'single_family',
#   'description_sold_price': 85000,
#   'description_sold_date': '1987-10-15',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=9711%20Bandera%20St%2C%20Los%20Angeles%2C%20CA%2090002&size=640x480&source=outdoor&signature=281DgVCwLnpNMSKai1ZdqtlVqq0=',
#   'location_address_line': '9711 Bandera St',
#   'location_address_postal_code': '90002',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 33.947793,
#   'location_address_coordinate_lon': -118.239965,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': True,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2024-04-05 00:52:08'},
#  {'property_id': '2490049093',
#   'list_price': 549000,
#   'status': 'for_sale',
#   'listing_id': '2965778876',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/2357-E-108th-St_Los-Angeles_CA_90059_M24900-49093',
#   'primary_photo': 'https://ap.rdcpix.com/657f4a60b83e6998dd3c63dedb985093l-m401013799s.jpg',
#   'description_beds': 3,
#   'description_baths': '2',
#   'description_sqft': 1128,
#   'description_lot_sqft': 3121,
#   'description_type': 'single_family',
#   'description_sold_price': 95000,
#   'description_sold_date': '2011-03-17',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=2357%20E%20108th%20St%2C%20Los%20Angeles%2C%20CA%2090059&size=640x480&source=outdoor&signature=HKf5ZrHx9ap4EwBmS-SK84JaNc8=',
#   'location_address_line': '2357 E 108th St',
#   'location_address_postal_code': '90059',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 33.937183,
#   'location_address_coordinate_lon': -118.229851,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': True,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2024-04-04 12:46:00'},
#  {'property_id': '2858683796',
#   'list_price': 550000,
#   'status': 'for_sale',
#   'listing_id': '2965773166',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/130-E-Lanzit-Ave_Los-Angeles_CA_90061_M28586-83796',
#   'primary_photo': 'https://ap.rdcpix.com/473bb451046b65bb1b7a802fef492fa9l-m2610413263s.jpg',
#   'description_beds': 4,
#   'description_baths': '2',
#   'description_sqft': 1348,
#   'description_lot_sqft': 3187,
#   'description_type': 'single_family',
#   'description_sold_price': None,
#   'description_sold_date': None,
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=130%20E%20Lanzit%20Ave%2C%20Los%20Angeles%2C%20CA%2090061&size=640x480&source=outdoor&signature=Ozk0mYxuvqcDIcbq1TsyArofTHU=',
#   'location_address_line': '130 E Lanzit Ave',
#   'location_address_postal_code': '90061',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 33.92952,
#   'location_address_coordinate_lon': -118.272786,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': True,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2024-04-04 04:23:24'},
#  {'property_id': '1963896326',
#   'list_price': 539000,
#   'status': 'for_sale',
#   'listing_id': '2965138212',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/819-N-Hicks-Ave_Los-Angeles_CA_90063_M19638-96326',
#   'primary_photo': 'https://ap.rdcpix.com/8e3abd966004715a8fb7e365af80aae1l-m1215009695s.jpg',
#   'description_beds': 3,
#   'description_baths': '2',
#   'description_sqft': 915,
#   'description_lot_sqft': 3618,
#   'description_type': 'single_family',
#   'description_sold_price': None,
#   'description_sold_date': None,
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=819%20N%20Hicks%20Ave%2C%20Los%20Angeles%2C%20CA%2090063&size=640x480&source=outdoor&signature=15M6g5QhbZGI5zIi5UduZDXDfEU=',
#   'location_address_line': '819 N Hicks Ave',
#   'location_address_postal_code': '90063',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 34.045336,
#   'location_address_coordinate_lon': -118.191085,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': False,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': True,
#   'list_date': '2024-03-14 18:52:36'},
#  {'property_id': '2251574881',
#   'list_price': 577000,
#   'status': 'for_sale',
#   'listing_id': '2965772674',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/1231-W-46th-St_Los-Angeles_CA_90037_M22515-74881',
#   'primary_photo': 'https://ap.rdcpix.com/d089ae6b583c5afbdf2b6dd808229a35l-m2277363959s.jpg',
#   'description_beds': 4,
#   'description_baths': '2',
#   'description_sqft': 1810,
#   'description_lot_sqft': 6552,
#   'description_type': 'single_family',
#   'description_sold_price': None,
#   'description_sold_date': None,
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=1231%20W%2046th%20St%2C%20Los%20Angeles%2C%20CA%2090037&size=640x480&source=outdoor&signature=DkSStqmNMVkONfFUxZahfskIivw=',
#   'location_address_line': '1231 W 46th St',
#   'location_address_postal_code': '90037',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 34.001938,
#   'location_address_coordinate_lon': -118.297064,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': True,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2024-04-04 04:23:24'},
#  {'property_id': '1848419320',
#   'list_price': 449900,
#   'status': 'for_sale',
#   'listing_id': '2965817066',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/11366-Acala-Ave_San-Fernando_CA_91340_M18484-19320',
#   'primary_photo': 'https://ap.rdcpix.com/74a7f09aa3261d3ba4d8f39deea4fe5cl-m1404574005s.jpg',
#   'description_beds': 1,
#   'description_baths': '1',
#   'description_sqft': 586,
#   'description_lot_sqft': 5002,
#   'description_type': 'single_family',
#   'description_sold_price': None,
#   'description_sold_date': None,
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=11366%20Acala%20Ave%2C%20San%20Fernando%2C%20CA%2091340&size=640x480&source=outdoor&signature=gQpeu1opFGC_KwpdFg2b8UjWvsQ=',
#   'location_address_line': '11366 Acala Ave',
#   'location_address_postal_code': '91340',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'San Fernando',
#   'location_address_coordinate_lat': 34.27724,
#   'location_address_coordinate_lon': -118.449072,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': True,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2024-04-05 02:26:52'},
#  {'property_id': '2425579013',
#   'list_price': 569900,
#   'status': 'for_sale',
#   'listing_id': '2965808179',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/10608-Hickory-St_Los-Angeles_CA_90002_M24255-79013',
#   'primary_photo': 'https://ap.rdcpix.com/a4b43f98b6b56574b4ae68c8f311d9b5l-m2968597149s.jpg',
#   'description_beds': 2,
#   'description_baths': '1',
#   'description_sqft': 680,
#   'description_lot_sqft': 5459,
#   'description_type': 'single_family',
#   'description_sold_price': 123000,
#   'description_sold_date': '2003-09-19',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=10608%20Hickory%20St%2C%20Los%20Angeles%2C%20CA%2090002&size=640x480&source=outdoor&signature=DAySYX7PXFNw7cHx30iMomtY1oE=',
#   'location_address_line': '10608 Hickory St',
#   'location_address_postal_code': '90002',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 33.939549,
#   'location_address_coordinate_lon': -118.235591,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': True,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2024-04-04 21:32:16'},
#  {'property_id': '1113087742',
#   'list_price': 598888,
#   'status': 'for_sale',
#   'listing_id': '2965679725',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/7053-Sunnycrest-Trl_Tujunga_CA_91042_M11130-87742',
#   'primary_photo': 'https://ap.rdcpix.com/0bf98bf876d6a3aae9f71ffeea4d1285l-m1384934374s.jpg',
#   'description_beds': 1,
#   'description_baths': '1',
#   'description_sqft': 800,
#   'description_lot_sqft': 4448,
#   'description_type': 'single_family',
#   'description_sold_price': None,
#   'description_sold_date': None,
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=7053%20Sunnycrest%20Trl%2C%20Tujunga%2C%20CA%2091042&size=640x480&source=outdoor&signature=Tb3oXYEGb4NPpcZkusRmcPluu-I=',
#   'location_address_line': '7053 Sunnycrest Trl',
#   'location_address_postal_code': '91042',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Tujunga',
#   'location_address_coordinate_lat': 34.254066,
#   'location_address_coordinate_lon': -118.284999,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': True,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2024-04-01 19:08:16'},
#  {'property_id': '1966816704',
#   'list_price': 595000,
#   'status': 'for_sale',
#   'listing_id': '2965381881',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/2450-E-115th-St_Los-Angeles_CA_90059_M19668-16704',
#   'primary_photo': 'https://ap.rdcpix.com/92a34ea868dae22a921cb0f04777bfcdl-m1652506273s.jpg',
#   'description_beds': 3,
#   'description_baths': '2',
#   'description_sqft': 1350,
#   'description_lot_sqft': 3598,
#   'description_type': 'single_family',
#   'description_sold_price': 290000,
#   'description_sold_date': '2016-06-16',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=2450%20E%20115th%20St%2C%20Los%20Angeles%2C%20CA%2090059&size=640x480&source=outdoor&signature=2BTBqE2msZiY4elZzZtSgMpX7FQ=',
#   'location_address_line': '2450 E 115th St',
#   'location_address_postal_code': '90059',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 33.930423,
#   'location_address_coordinate_lon': -118.228398,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': True,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2024-03-22 03:58:41'},
#  {'property_id': '2264017854',
#   'list_price': 515000,
#   'status': 'for_sale',
#   'listing_id': '2965714275',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/1523-E-L-St_Wilmington_CA_90744_M22640-17854',
#   'primary_photo': 'https://ap.rdcpix.com/ae5676c035bcf25dc5ad118a4fb09272l-m3484898271s.jpg',
#   'description_beds': 3,
#   'description_baths': '2',
#   'description_sqft': 1296,
#   'description_lot_sqft': 5205,
#   'description_type': 'single_family',
#   'description_sold_price': 23000,
#   'description_sold_date': '1975-07-07',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=1523%20E%20L%20St%2C%20Wilmington%2C%20CA%2090744&size=640x480&source=outdoor&signature=Eq2LO6aOylGqd7V_wDza3OnhpNo=',
#   'location_address_line': '1523 E L St',
#   'location_address_postal_code': '90744',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Wilmington',
#   'location_address_coordinate_lat': 33.787516,
#   'location_address_coordinate_lon': -118.244288,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': True,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2024-04-02 18:52:24'},
#  {'property_id': '1443887365',
#   'list_price': 375000,
#   'status': 'for_sale',
#   'listing_id': '2964286959',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/4112-Telluride-St_Los-Angeles_CA_90031_M14438-87365',
#   'primary_photo': 'https://ap.rdcpix.com/c16d93ed61fd98a155932d6b0dea0611l-b3144888058s.jpg',
#   'description_beds': 3,
#   'description_baths': '1',
#   'description_sqft': 1158,
#   'description_lot_sqft': 4473,
#   'description_type': 'single_family',
#   'description_sold_price': 375000,
#   'description_sold_date': '2021-12-21',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=4112%20Telluride%20St%2C%20Los%20Angeles%2C%20CA%2090031&size=640x480&source=outdoor&signature=-hyz3ij88gwn30v6ndp3vgS2F38=',
#   'location_address_line': '4112 Telluride St',
#   'location_address_postal_code': '90031',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 34.081213,
#   'location_address_coordinate_lon': -118.198892,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': False,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2024-02-20 23:16:06'},
#  {'property_id': '2647140265',
#   'list_price': 550000,
#   'status': 'for_sale',
#   'listing_id': '2965160041',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/10140-Vena-Ave_Arleta_CA_91331_M26471-40265',
#   'primary_photo': 'https://ap.rdcpix.com/2647b246c1a43664eae6780b9aa41a3el-m345982109s.jpg',
#   'description_beds': 4,
#   'description_baths': '2',
#   'description_sqft': 1243,
#   'description_lot_sqft': 7002,
#   'description_type': 'single_family',
#   'description_sold_price': 21500,
#   'description_sold_date': '1969-12-09',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=10140%20Vena%20Ave%2C%20Arleta%2C%20CA%2091331&size=640x480&source=outdoor&signature=V912v3b1XOdmkUxD6Os-s1lO81g=',
#   'location_address_line': '10140 Vena Ave',
#   'location_address_postal_code': '91331',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Arleta',
#   'location_address_coordinate_lat': 34.254798,
#   'location_address_coordinate_lon': -118.434739,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': False,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': True,
#   'flags_is_contingent': None,
#   'list_date': '2024-03-15 04:22:05'},
#  {'property_id': '1856738369',
#   'list_price': 529000,
#   'status': 'for_sale',
#   'listing_id': '2958779636',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/1118-W-Cruces-St_Wilmington_CA_90744_M18567-38369',
#   'primary_photo': 'https://ap.rdcpix.com/bd0a91e562e3890348b2d750a2f442acl-m1350864065s.jpg',
#   'description_beds': 3,
#   'description_baths': '1',
#   'description_sqft': 939,
#   'description_lot_sqft': 5040,
#   'description_type': 'single_family',
#   'description_sold_price': None,
#   'description_sold_date': None,
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=1118%20W%20Cruces%20St%2C%20Wilmington%2C%20CA%2090744&size=640x480&source=outdoor&signature=iODA0s8Sn386DarNtEIxYVoYLmo=',
#   'location_address_line': '1118 W Cruces St',
#   'location_address_postal_code': '90744',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Wilmington',
#   'location_address_coordinate_lat': 33.791114,
#   'location_address_coordinate_lon': -118.277129,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': False,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2023-08-16 23:41:39'},
#  {'property_id': '2045946485',
#   'list_price': 549000,
#   'status': 'for_sale',
#   'listing_id': '2965769552',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/6031-4th-Ave_Los-Angeles_CA_90043_M20459-46485',
#   'primary_photo': 'https://ap.rdcpix.com/04ab51dc8e833e367304cec8e15a3869l-m3541939115s.jpg',
#   'description_beds': 2,
#   'description_baths': '1',
#   'description_sqft': 1008,
#   'description_lot_sqft': 4798,
#   'description_type': 'single_family',
#   'description_sold_price': None,
#   'description_sold_date': None,
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=6031%204th%20Ave%2C%20Los%20Angeles%2C%20CA%2090043&size=640x480&source=outdoor&signature=QAWUB9SnXcgSQ82Sc9K686q-4Ls=',
#   'location_address_line': '6031 4th Ave',
#   'location_address_postal_code': '90043',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 33.984555,
#   'location_address_coordinate_lon': -118.321868,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': True,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2024-04-04 01:34:41'},
#  {'property_id': '2324364714',
#   'list_price': 599000,
#   'status': 'for_sale',
#   'listing_id': '2965752772',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/605-W-108th-St_Los-Angeles_CA_90044_M23243-64714',
#   'primary_photo': 'https://ap.rdcpix.com/ed5ec1d373a10fd2b82060db2a9be680l-m83192557s.jpg',
#   'description_beds': 2,
#   'description_baths': '1',
#   'description_sqft': 966,
#   'description_lot_sqft': 4803,
#   'description_type': 'single_family',
#   'description_sold_price': 440000,
#   'description_sold_date': '2018-12-28',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=605%20W%20108th%20St%2C%20Los%20Angeles%2C%20CA%2090044&size=640x480&source=outdoor&signature=Ebty0p1vZa3BXWyu7pQ9fF6TCnc=',
#   'location_address_line': '605 W 108th St',
#   'location_address_postal_code': '90044',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 33.938557,
#   'location_address_coordinate_lon': -118.285097,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': True,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': True,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2024-04-03 18:12:30'},
#  {'property_id': '2993925754',
#   'list_price': 599000,
#   'status': 'for_sale',
#   'listing_id': '2965537359',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/8510-Wilbur-Ave_Northridge_CA_91324_M29939-25754',
#   'primary_photo': 'https://ap.rdcpix.com/37c80a757151f153d326e5766f3ea9afl-m952842171s.jpg',
#   'description_beds': 3,
#   'description_baths': '1',
#   'description_sqft': 852,
#   'description_lot_sqft': 9152,
#   'description_type': 'single_family',
#   'description_sold_price': None,
#   'description_sold_date': None,
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=8510%20Wilbur%20Ave%2C%20Northridge%2C%20CA%2091324&size=640x480&source=outdoor&signature=p5WT0KnmtsABfnFpseqwIxmtzZ0=',
#   'location_address_line': '8510 Wilbur Ave',
#   'location_address_postal_code': '91324',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Northridge',
#   'location_address_coordinate_lat': 34.225034,
#   'location_address_coordinate_lon': -118.544485,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': False,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': True,
#   'flags_is_contingent': None,
#   'list_date': '2024-03-27 22:13:31'},
#  {'property_id': '2028078429',
#   'list_price': 596900,
#   'status': 'for_sale',
#   'listing_id': '2965484618',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/10417-El-Dorado-Ave_Pacoima_CA_91331_M20280-78429',
#   'primary_photo': 'https://ap.rdcpix.com/91605a442ae674273530264050f19d0bl-m340437803s.jpg',
#   'description_beds': 3,
#   'description_baths': '1',
#   'description_sqft': 732,
#   'description_lot_sqft': 8418,
#   'description_type': 'single_family',
#   'description_sold_price': None,
#   'description_sold_date': None,
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=10417%20El%20Dorado%20Ave%2C%20Pacoima%2C%20CA%2091331&size=640x480&source=outdoor&signature=cEIUpIHFXntnEJEuI-DUiw1vFOY=',
#   'location_address_line': '10417 El Dorado Ave',
#   'location_address_postal_code': '91331',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Pacoima',
#   'location_address_coordinate_lat': 34.259218,
#   'location_address_coordinate_lon': -118.418099,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': True,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2024-03-26 12:28:55'},
#  {'property_id': '2954446600',
#   'list_price': 598888,
#   'status': 'for_sale',
#   'listing_id': '2965681114',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/7649-Thousand-Oaks-Dr_Tujunga_CA_91042_M29544-46600',
#   'primary_photo': 'https://ap.rdcpix.com/6e505a2c6a4dee9642e1688fb383a5e1l-m3972856133s.jpg',
#   'description_beds': 2,
#   'description_baths': '1',
#   'description_sqft': 720,
#   'description_lot_sqft': 7310,
#   'description_type': 'single_family',
#   'description_sold_price': None,
#   'description_sold_date': None,
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=7649%20Thousand%20Oaks%20Dr%2C%20Tujunga%2C%20CA%2091042&size=640x480&source=outdoor&signature=L4SrHunrjeH5d7OuKcCOmodbohg=',
#   'location_address_line': '7649 Thousand Oaks Dr',
#   'location_address_postal_code': '91042',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Tujunga',
#   'location_address_coordinate_lat': 34.252251,
#   'location_address_coordinate_lon': -118.299572,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': True,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2024-04-01 19:42:41'},
#  {'property_id': '1165883433',
#   'list_price': 595000,
#   'status': 'for_sale',
#   'listing_id': '2965755984',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/3275-Folsom-St_Los-Angeles_CA_90063_M11658-83433',
#   'primary_photo': 'https://ap.rdcpix.com/0816e47c35735f519a26669f1110197al-m361134871s.jpg',
#   'description_beds': 2,
#   'description_baths': '1',
#   'description_sqft': 856,
#   'description_lot_sqft': 5657,
#   'description_type': 'single_family',
#   'description_sold_price': 73000,
#   'description_sold_date': '1986-04-23',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=3275%20Folsom%20St%2C%20Los%20Angeles%2C%20CA%2090063&size=640x480&source=outdoor&signature=5IriXaBSibGDdTW5f3GGZO3My48=',
#   'location_address_line': '3275 Folsom St',
#   'location_address_postal_code': '90063',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 34.043645,
#   'location_address_coordinate_lon': -118.192845,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': True,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2024-04-03 19:22:05'},
#  {'property_id': '1468296557',
#   'list_price': 500000,
#   'status': 'for_sale',
#   'listing_id': '2965765570',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/4416-Radium-Dr_Los-Angeles_CA_90032_M14682-96557',
#   'primary_photo': 'https://ap.rdcpix.com/4e1965e9bf2cd2c91980c95c2754edcel-m3282387862s.jpg',
#   'description_beds': 2,
#   'description_baths': '1',
#   'description_sqft': 793,
#   'description_lot_sqft': 4317,
#   'description_type': 'single_family',
#   'description_sold_price': None,
#   'description_sold_date': None,
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=4416%20Radium%20Dr%2C%20Los%20Angeles%2C%20CA%2090032&size=640x480&source=outdoor&signature=EmiDTZKgKIKYv1SxRFydLbkzzNU=',
#   'location_address_line': '4416 Radium Dr',
#   'location_address_postal_code': '90032',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 34.079241,
#   'location_address_coordinate_lon': -118.19481,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': True,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2024-04-03 23:07:56'},
#  {'property_id': '1958226828',
#   'list_price': 350000,
#   'status': 'for_sale',
#   'listing_id': '620953204',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/9522-Hickory-St_Los-Angeles_CA_90002_M19582-26828',
#   'primary_photo': 'https://ap.rdcpix.com/7754c33bdb079f5be1563795069e4697l-m1234861304s.jpg',
#   'description_beds': 3,
#   'description_baths': '1',
#   'description_sqft': 1260,
#   'description_lot_sqft': 5408,
#   'description_type': 'single_family',
#   'description_sold_price': 250000,
#   'description_sold_date': '2014-07-11',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=9522%20Hickory%20St%2C%20Los%20Angeles%2C%20CA%2090002&size=640x480&source=outdoor&signature=lTBjYRajj9p829PH6ygcqopUex4=',
#   'location_address_line': '9522 Hickory St',
#   'location_address_postal_code': '90002',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 33.949858,
#   'location_address_coordinate_lon': -118.234832,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': False,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': True,
#   'flags_is_contingent': None,
#   'list_date': '2019-03-16 00:10:41'},
#  {'property_id': '1854083743',
#   'list_price': 590000,
#   'status': 'for_sale',
#   'listing_id': '2964239736',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/14687-Harding-St_San-Fernando_CA_91340_M18540-83743',
#   'primary_photo': 'https://ap.rdcpix.com/994f989e07d19ea9c2aaad621be6e079l-m3997376285s.jpg',
#   'description_beds': 3,
#   'description_baths': '1',
#   'description_sqft': 960,
#   'description_lot_sqft': 6533,
#   'description_type': 'single_family',
#   'description_sold_price': 46000,
#   'description_sold_date': '1978-11-09',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=14687%20Harding%20St%2C%20San%20Fernando%2C%20CA%2091340&size=640x480&source=outdoor&signature=qTsrEUtKViDz2DOInH04f7QrKHQ=',
#   'location_address_line': '14687 Harding St',
#   'location_address_postal_code': '91340',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'San Fernando',
#   'location_address_coordinate_lat': 34.280059,
#   'location_address_coordinate_lon': -118.453393,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': False,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2024-02-19 05:21:56'},
#  {'property_id': '1085809072',
#   'list_price': 350000,
#   'status': 'for_sale',
#   'listing_id': '2954421261',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/7115-Shadygrove-St_Tujunga_CA_91042_M10858-09072',
#   'primary_photo': 'https://ap.rdcpix.com/a906675d9d201b00771edb12ada4af03l-m4012555766s.jpg',
#   'description_beds': 3,
#   'description_baths': '1',
#   'description_sqft': 1079,
#   'description_lot_sqft': 5000,
#   'description_type': 'single_family',
#   'description_sold_price': 30000,
#   'description_sold_date': '1980-07-03',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=7115%20Shadygrove%20St%2C%20Tujunga%2C%20CA%2091042&size=640x480&source=outdoor&signature=jQs7lS0UFyMZFrmlawJ8CBZYy9E=',
#   'location_address_line': '7115 Shadygrove St',
#   'location_address_postal_code': '91042',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Tujunga',
#   'location_address_coordinate_lat': 34.247481,
#   'location_address_coordinate_lon': -118.286403,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': False,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': True,
#   'flags_is_contingent': None,
#   'list_date': '2023-05-09 09:16:01'},
#  {'property_id': '2263496131',
#   'list_price': 599000,
#   'status': 'for_sale',
#   'listing_id': '2965698714',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/940-Pioneer-Ave_Wilmington_CA_90744_M22634-96131',
#   'primary_photo': 'https://ap.rdcpix.com/b0514116e507bb4beba550021601e263l-b958658702s.jpg',
#   'description_beds': 2,
#   'description_baths': '1',
#   'description_sqft': 720,
#   'description_lot_sqft': 4539,
#   'description_type': 'single_family',
#   'description_sold_price': None,
#   'description_sold_date': None,
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=940%20Pioneer%20Ave%2C%20Wilmington%2C%20CA%2090744&size=640x480&source=outdoor&signature=HGbHlZoo7O5YD9UZXDmRqwAxuIg=',
#   'location_address_line': '940 Pioneer Ave',
#   'location_address_postal_code': '90744',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Wilmington',
#   'location_address_coordinate_lat': 33.783362,
#   'location_address_coordinate_lon': -118.248295,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': True,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': None,
#   'list_date': '2024-04-02 12:19:03'},
#  {'property_id': '2287237166',
#   'list_price': 469000,
#   'status': 'for_sale',
#   'listing_id': '2965509038',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/11533-Dronfield-Ave_Pacoima_CA_91331_M22872-37166',
#   'primary_photo': 'https://ap.rdcpix.com/d2345f8a4e3268339b21ae693e13bbecl-m1532183448s.jpg',
#   'description_beds': 2,
#   'description_baths': '1',
#   'description_sqft': 567,
#   'description_lot_sqft': 10402,
#   'description_type': 'single_family',
#   'description_sold_price': None,
#   'description_sold_date': None,
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=11533%20Dronfield%20Ave%2C%20Pacoima%2C%20CA%2091331&size=640x480&source=outdoor&signature=7QOzSg5E-s7ZZEq7c1FT-K5W_sM=',
#   'location_address_line': '11533 Dronfield Ave',
#   'location_address_postal_code': '91331',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Pacoima',
#   'location_address_coordinate_lat': 34.279078,
#   'location_address_coordinate_lon': -118.406161,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': True,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': None,
#   'flags_is_contingent': True,
#   'list_date': '2024-03-27 00:21:55'},
#  {'property_id': '1644654221',
#   'list_price': 395000,
#   'status': 'for_sale',
#   'listing_id': '2964111448',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/23720-Hartland-St_West-Hills_CA_91307_M16446-54221',
#   'primary_photo': 'https://ap.rdcpix.com/2356a1b49ce40bea7c6c37f48187d591l-m2488674868s.jpg',
#   'description_beds': 3,
#   'description_baths': '2',
#   'description_sqft': 1250,
#   'description_lot_sqft': 9687,
#   'description_type': 'single_family',
#   'description_sold_price': 28000,
#   'description_sold_date': '1965-12-31',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=23720%20Hartland%20St%2C%20West%20Hills%2C%20CA%2091307&size=640x480&source=outdoor&signature=M0r-mp3xqYgb52OM-juJSD4CsLo=',
#   'location_address_line': '23720 Hartland St',
#   'location_address_postal_code': '91307',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'West Hills',
#   'location_address_coordinate_lat': 34.194008,
#   'location_address_coordinate_lon': -118.643279,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': False,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': True,
#   'flags_is_contingent': None,
#   'list_date': '2024-02-14 19:57:49'},
#  {'property_id': '1202026323',
#   'list_price': 425000,
#   'status': 'for_sale',
#   'listing_id': '2965764754',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/240-E-77th-St_Los-Angeles_CA_90003_M12020-26323',
#   'primary_photo': 'https://ap.rdcpix.com/4a74aed047c1c56fcdfea9200fd677e1l-m414952424s.jpg',
#   'description_beds': 2,
#   'description_baths': '1',
#   'description_sqft': 732,
#   'description_lot_sqft': 3825,
#   'description_type': 'single_family',
#   'description_sold_price': 189000,
#   'description_sold_date': '2004-09-16',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=240%20E%2077th%20St%2C%20Los%20Angeles%2C%20CA%2090003&size=640x480&source=outdoor&signature=wWA9OJlrgiMmvasGgqu_bk9c3sg=',
#   'location_address_line': '240 E 77th St',
#   'location_address_postal_code': '90003',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 33.96939,
#   'location_address_coordinate_lon': -118.270381,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': True,
# ...
#   'status': 'for_sale',
#   'listing_id': '2963537062',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/10327-Anzac-Ave_Los-Angeles_CA_90002_M23875-30486',
#   'primary_photo': 'https://ap.rdcpix.com/611fa894711b317c82147ef66deee383l-m4143376352s.jpg',
#   'description_beds': 3,
#   'description_baths': '2.5',
#   'description_sqft': 1688,
#   'description_lot_sqft': 3252,
#   'description_type': 'single_family',
#   'description_sold_price': 400000,
#   'description_sold_date': '2019-12-06',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=10327%20Anzac%20Ave%2C%20Los%20Angeles%2C%20CA%2090002&size=640x480&source=outdoor&signature=FYW-7U-ujesn6q5GgZhX-7PlQpY=',
#   'location_address_line': '10327 Anzac Ave',
#   'location_address_postal_code': '90002',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 33.94231,
#   'location_address_coordinate_lon': -118.238222,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': False,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': True,
#   'flags_is_contingent': None,
#   'list_date': '2024-01-27 13:13:04'},
#  {'property_id': '1980652365',
#   'list_price': 550000,
#   'status': 'for_sale',
#   'listing_id': '2962647580',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/1715-E-113th-St_Los-Angeles_CA_90059_M19806-52365',
#   'primary_photo': 'https://ap.rdcpix.com/270d55b6b48a6ef64e7772252571c390l-m925176438s.jpg',
#   'description_beds': 3,
#   'description_baths': '2',
#   'description_sqft': 1387,
#   'description_lot_sqft': 3421,
#   'description_type': 'single_family',
#   'description_sold_price': 438000,
#   'description_sold_date': '2007-02-16',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=1715%20E%20113th%20St%2C%20Los%20Angeles%2C%20CA%2090059&size=640x480&source=outdoor&signature=JBNmx7kej4U92Ci9na8nmufMJYs=',
#   'location_address_line': '1715 E 113th St',
#   'location_address_postal_code': '90059',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 33.932341,
#   'location_address_coordinate_lon': -118.242902,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': False,
#   'flags_is_price_reduced': False,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': True,
#   'flags_is_contingent': None,
#   'list_date': '2023-12-19 21:17:00'},
#  {'property_id': '2469403761',
#   'list_price': 499999,
#   'status': 'for_sale',
#   'listing_id': '2964333527',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/11007-Watts-Ave_Los-Angeles_CA_90059_M24694-03761',
#   'primary_photo': 'https://ap.rdcpix.com/beab1dc1d4d37c520086a29af96ebd2dl-m2606326914s.jpg',
#   'description_beds': 2,
#   'description_baths': '1',
#   'description_sqft': 1020,
#   'description_lot_sqft': 6243,
#   'description_type': 'single_family',
#   'description_sold_price': None,
#   'description_sold_date': None,
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=11007%20Watts%20Ave%2C%20Los%20Angeles%2C%20CA%2090059&size=640x480&source=outdoor&signature=dXrfGMrWLTERlyKiy5d8oP8bHd8=',
#   'location_address_line': '11007 Watts Ave',
#   'location_address_postal_code': '90059',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 33.93504,
#   'location_address_coordinate_lon': -118.228175,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': False,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': True,
#   'flags_is_contingent': None,
#   'list_date': '2024-02-22 13:36:32'},
#  {'property_id': '2351307990',
#   'list_price': 600000,
#   'status': 'for_sale',
#   'listing_id': '2960296754',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/10004-S-San-Pedro-St_Los-Angeles_CA_90003_M23513-07990',
#   'primary_photo': 'https://ap.rdcpix.com/f2cfffd25ce7519b0ef61b843b94b3d0l-m1508840771s.jpg',
#   'description_beds': 2,
#   'description_baths': '1',
#   'description_sqft': 924,
#   'description_lot_sqft': 4069,
#   'description_type': 'single_family',
#   'description_sold_price': 160000,
#   'description_sold_date': '2003-11-19',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=10004%20S%20San%20Pedro%20St%2C%20Los%20Angeles%2C%20CA%2090003&size=640x480&source=outdoor&signature=FzRN2biHZJkByTyPiVtuaf_1TNU=',
#   'location_address_line': '10004 S San Pedro St',
#   'location_address_postal_code': '90003',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 33.945391,
#   'location_address_coordinate_lon': -118.269216,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': False,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': True,
#   'flags_is_contingent': None,
#   'list_date': '2024-01-11 02:04:09'},
#  {'property_id': '2601229847',
#   'list_price': 500000,
#   'status': 'for_sale',
#   'listing_id': '2963391543',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/1246-E-35th-St_Los-Angeles_CA_90011_M26012-29847',
#   'primary_photo': 'https://ap.rdcpix.com/287f789c59d384e296576583ea432b1dl-m3375953458s.jpg',
#   'description_beds': 2,
#   'description_baths': '1',
#   'description_sqft': 1278,
#   'description_lot_sqft': 4601,
#   'description_type': 'single_family',
#   'description_sold_price': None,
#   'description_sold_date': None,
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=1246%20E%2035th%20St%2C%20Los%20Angeles%2C%20CA%2090011&size=640x480&source=outdoor&signature=iQjdpk0GGszdA_-aGpys2eympSk=',
#   'location_address_line': '1246 E 35th St',
#   'location_address_postal_code': '90011',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 34.011766,
#   'location_address_coordinate_lon': -118.252986,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': False,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': True,
#   'flags_is_contingent': None,
#   'list_date': '2024-01-23 00:52:13'},
#  {'property_id': '1995902696',
#   'list_price': 595000,
#   'status': 'for_sale',
#   'listing_id': '2965509885',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/736-E-103rd-St_Los-Angeles_CA_90002_M19959-02696',
#   'primary_photo': 'https://ap.rdcpix.com/d3eb1ab5615be2de17ac552ffe29327el-m2628131200s.jpg',
#   'description_beds': 3,
#   'description_baths': '1',
#   'description_sqft': 972,
#   'description_lot_sqft': 5480,
#   'description_type': 'single_family',
#   'description_sold_price': 425000,
#   'description_sold_date': '2019-10-18',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=736%20E%20103rd%20St%2C%20Los%20Angeles%2C%20CA%2090002&size=640x480&source=outdoor&signature=evFenVMwCGkiNIm7rmOhfIYovPY=',
#   'location_address_line': '736 E 103rd St',
#   'location_address_postal_code': '90002',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 33.943062,
#   'location_address_coordinate_lon': -118.261202,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': False,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': True,
#   'flags_is_contingent': None,
#   'list_date': '2024-03-27 00:52:40'},
#  {'property_id': '2595746678',
#   'list_price': 467000,
#   'status': 'for_sale',
#   'listing_id': '2965363732',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/6213-Haas-Ave_Los-Angeles_CA_90047_M25957-46678',
#   'primary_photo': 'https://ap.rdcpix.com/8a14ad9fb64c89a1de47e4c1624d6fa9l-m1208019902s.jpg',
#   'description_beds': 2,
#   'description_baths': '1',
#   'description_sqft': 988,
#   'description_lot_sqft': 4845,
#   'description_type': 'single_family',
#   'description_sold_price': 382000,
#   'description_sold_date': '2006-09-22',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=6213%20Haas%20Ave%2C%20Los%20Angeles%2C%20CA%2090047&size=640x480&source=outdoor&signature=yyiQljrF5zof2KfHm_KzQYCHX-0=',
#   'location_address_line': '6213 Haas Ave',
#   'location_address_postal_code': '90047',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 33.982961,
#   'location_address_coordinate_lon': -118.317047,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': False,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': True,
#   'flags_is_contingent': None,
#   'list_date': '2024-03-21 18:58:34'},
#  {'property_id': '2083440395',
#   'list_price': 470000,
#   'status': 'for_sale',
#   'listing_id': '2965467777',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/125-W-97th-St_Los-Angeles_CA_90003_M20834-40395',
#   'primary_photo': 'https://ap.rdcpix.com/174bb1855c8987d1ea4f1e7bd7c2c2a1l-m1081864524s.jpg',
#   'description_beds': 2,
#   'description_baths': '1',
#   'description_sqft': 720,
#   'description_lot_sqft': 5406,
#   'description_type': 'single_family',
#   'description_sold_price': 164000,
#   'description_sold_date': '2010-10-21',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=125%20W%2097th%20St%2C%20Los%20Angeles%2C%20CA%2090003&size=640x480&source=outdoor&signature=zsd7It_CmvgKyw99DDb88UhcVNQ=',
#   'location_address_line': '125 W 97th St',
#   'location_address_postal_code': '90003',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 33.948547,
#   'location_address_coordinate_lon': -118.274962,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': False,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': True,
#   'flags_is_contingent': None,
#   'list_date': '2024-03-25 18:27:33'},
#  {'property_id': '1315128458',
#   'list_price': 575000,
#   'status': 'for_sale',
#   'listing_id': '2962848990',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/8510-S-Fir-Ave_Los-Angeles_CA_90001_M13151-28458',
#   'primary_photo': 'https://ap.rdcpix.com/694418fd38e68f969e746789184cbd15l-b3874326282s.jpg',
#   'description_beds': 2,
#   'description_baths': '1',
#   'description_sqft': 832,
#   'description_lot_sqft': 6694,
#   'description_type': 'single_family',
#   'description_sold_price': None,
#   'description_sold_date': None,
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=8510%20S%20Fir%20Ave%2C%20Los%20Angeles%2C%20CA%2090001&size=640x480&source=outdoor&signature=RT1uH_Q6ym71qPmc1cKUROY0lAU=',
#   'location_address_line': '8510 S Fir Ave',
#   'location_address_postal_code': '90001',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 33.960727,
#   'location_address_coordinate_lon': -118.237068,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': False,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': True,
#   'flags_is_contingent': None,
#   'list_date': '2024-01-02 19:46:53'},
#  {'property_id': '2400291886',
#   'list_price': 440000,
#   'status': 'for_sale',
#   'listing_id': '2963526981',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/1516-E-50th-St_Los-Angeles_CA_90011_M24002-91886',
#   'primary_photo': 'https://ap.rdcpix.com/a9449708170f87ca7aca66021a103a7al-m4260980176s.jpg',
#   'description_beds': 1,
#   'description_baths': '1',
#   'description_sqft': 832,
#   'description_lot_sqft': 5402,
#   'description_type': 'single_family',
#   'description_sold_price': 180000,
#   'description_sold_date': '2004-01-30',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=1516%20E%2050th%20St%2C%20Los%20Angeles%2C%20CA%2090011&size=640x480&source=outdoor&signature=dmSDPh5ZZqjOSz-VEi-8RmQKv9U=',
#   'location_address_line': '1516 E 50th St',
#   'location_address_postal_code': '90011',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 33.997244,
#   'location_address_coordinate_lon': -118.247102,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': False,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': True,
#   'flags_is_contingent': None,
#   'list_date': '2024-01-26 22:41:43'},
#  {'property_id': '1404380391',
#   'list_price': 425000,
#   'status': 'for_sale',
#   'listing_id': '2964454962',
#   'permalink': 'https://www.realtor.com/realestateandhomes-detail/8511-Stanford-Ave_Los-Angeles_CA_90001_M14043-80391',
#   'primary_photo': '',
#   'description_beds': 1,
#   'description_baths': '1',
#   'description_sqft': 684,
#   'description_lot_sqft': 2646,
#   'description_type': 'single_family',
#   'description_sold_price': 38500,
#   'description_sold_date': '1987-11-30',
#   'location_street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=8511%20Stanford%20Ave%2C%20Los%20Angeles%2C%20CA%2090001&size=640x480&source=outdoor&signature=7WvjAwuQh47B2O7EJB0DG_LP-Ms=',
#   'location_address_line': '8511 Stanford Ave',
#   'location_address_postal_code': '90001',
#   'location_address_state': 'California',
#   'location_address_state_code': 'CA',
#   'location_address_city': 'Los Angeles',
#   'location_address_coordinate_lat': 33.960688,
#   'location_address_coordinate_lon': -118.263101,
#   'location_county_name': 'Los Angeles',
#   'location_county_fips_code': '06037',
#   'flags_is_coming_soon': None,
#   'flags_is_new_listing': False,
#   'flags_is_price_reduced': None,
#   'flags_is_foreclosure': None,
#   'flags_is_new_construction': None,
#   'flags_is_pending': True,
#   'flags_is_contingent': None,
#   'list_date': '2024-02-26 20:17:49'}]

# %%
df
# Out:
#     property_id  list_price    status  listing_id  \
# 0    2769011270      399000  for_sale  2965588367
# 1    1142069273      600000  for_sale  2965694229
# 2    2484506523      599000  for_sale  2959469993
# 3    2350354300      549950  for_sale  2965341897
# 4    1825932732      587000  for_sale  2965607706
# ..          ...         ...       ...         ...
# 202  2595746678      467000  for_sale  2965363732
# 203  2083440395      470000  for_sale  2965467777
# 204  1315128458      575000  for_sale  2962848990
# 205  2400291886      440000  for_sale  2963526981
# 206  1404380391      425000  for_sale  2964454962
#
#                                              permalink  \
# 0    https://www.realtor.com/realestateandhomes-det...
# 1    https://www.realtor.com/realestateandhomes-det...
# 2    https://www.realtor.com/realestateandhomes-det...
# 3    https://www.realtor.com/realestateandhomes-det...
# 4    https://www.realtor.com/realestateandhomes-det...
# ..                                                 ...
# 202  https://www.realtor.com/realestateandhomes-det...
# 203  https://www.realtor.com/realestateandhomes-det...
# 204  https://www.realtor.com/realestateandhomes-det...
# 205  https://www.realtor.com/realestateandhomes-det...
# 206  https://www.realtor.com/realestateandhomes-det...
#
#                                          primary_photo  \
# 0    https://ap.rdcpix.com/bfbe22246f91502763b8ee91...
# 1    https://ap.rdcpix.com/ba7307d8f912ede7e832ffa2...
# 2    https://ap.rdcpix.com/77b9cc2e89ac789f7f2e27f5...
# 3    https://ap.rdcpix.com/657b8269268d4e99102f034c...
# 4    https://ap.rdcpix.com/7d9810be229e1fb18a4f7ec7...
# ..                                                 ...
# 202  https://ap.rdcpix.com/8a14ad9fb64c89a1de47e4c1...
# 203  https://ap.rdcpix.com/174bb1855c8987d1ea4f1e7b...
# 204  https://ap.rdcpix.com/694418fd38e68f969e746789...
# 205  https://ap.rdcpix.com/a9449708170f87ca7aca6602...
# 206
#
#                                            description  \
# 0    {'beds': 3, 'baths': '1', 'sqft': 967, 'lot_sq...
# 1    {'beds': 3, 'baths': '2', 'sqft': 1443, 'lot_s...
# 2    {'beds': 3, 'baths': '3', 'sqft': 2500, 'lot_s...
# 3    {'beds': 2, 'baths': '1', 'sqft': 869, 'lot_sq...
# 4    {'beds': 5, 'baths': '3', 'sqft': 1213, 'lot_s...
# ..                                                 ...
# 202  {'beds': 2, 'baths': '1', 'sqft': 988, 'lot_sq...
# 203  {'beds': 2, 'baths': '1', 'sqft': 720, 'lot_sq...
# 204  {'beds': 2, 'baths': '1', 'sqft': 832, 'lot_sq...
# 205  {'beds': 1, 'baths': '1', 'sqft': 832, 'lot_sq...
# 206  {'beds': 1, 'baths': '1', 'sqft': 684, 'lot_sq...
#
#                                               location  \
# 0    {'street_view_url': 'https://maps.googleapis.c...
# 1    {'street_view_url': 'https://maps.googleapis.c...
# 2    {'street_view_url': 'https://maps.googleapis.c...
# 3    {'street_view_url': 'https://maps.googleapis.c...
# 4    {'street_view_url': 'https://maps.googleapis.c...
# ..                                                 ...
# 202  {'street_view_url': 'https://maps.googleapis.c...
# 203  {'street_view_url': 'https://maps.googleapis.c...
# 204  {'street_view_url': 'https://maps.googleapis.c...
# 205  {'street_view_url': 'https://maps.googleapis.c...
# 206  {'street_view_url': 'https://maps.googleapis.c...
#
#                                                  flags            list_date
# 0    {'is_coming_soon': None, 'is_new_listing': Tru...  2024-03-28 21:15:38
# 1    {'is_coming_soon': None, 'is_new_listing': Tru...  2024-04-02 01:57:32
# 2    {'is_coming_soon': None, 'is_new_listing': Fal...  2023-09-07 23:11:05
# 3    {'is_coming_soon': None, 'is_new_listing': Fal...  2024-03-21 05:17:07
# 4    {'is_coming_soon': None, 'is_new_listing': Tru...  2024-03-29 12:12:31
# ..                                                 ...                  ...
# 202  {'is_coming_soon': None, 'is_new_listing': Fal...  2024-03-21 18:58:34
# 203  {'is_coming_soon': None, 'is_new_listing': Fal...  2024-03-25 18:27:33
# 204  {'is_coming_soon': None, 'is_new_listing': Fal...  2024-01-02 19:46:53
# 205  {'is_coming_soon': None, 'is_new_listing': Fal...  2024-01-26 22:41:43
# 206  {'is_coming_soon': None, 'is_new_listing': Fal...  2024-02-26 20:17:49
#
# [207 rows x 10 columns]
